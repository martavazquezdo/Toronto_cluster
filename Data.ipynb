# %% [markdown]
# ## CLUSTER OF THE NEIGHBOUHOODS OF TORONTO

# %% [markdown]
# This project cluster the neigbourhood of Toronto from Wikipedia data

# %% [markdown]
# Before we start with the main lab content, let's download all the dependencies that we will need.

# %%
import pandas as pd
import requests
import numpy as np

# %%
#!pip3 install lxml  #this doesn't work and I always get the message "lxml not found, please install it" when trying to scrape the wiki table

# %% [markdown]
# ### DOWNLOAD THE DATA AND SAVE IT IN A PANDAS DATA FRAME

# %% [raw]
# tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M', header=0)
#
# headings = ['Postal Code', 'Borough', 'Neighbourhood']
#
# for table in tables:
#     current_headings = table.columns.values[:3]
#     if len(current_headings) != len(headings):
#         continue
#     if all(current_headings == headings):
#         break
#
# table[headings].to_csv('Toronto_data.csv', sep=';', header=True, index=False)
#
# #Note: It was imposible to me to get the table directly in the notebook. I always got an error with lxml parse. I try to install it but it was imposible to me so the previous code was run on my personal computer.
# #I then saved the table on a csv and import that csv file here

# %%
#This is to charge the data from the csv file due to the problems in the lxml intalation on the notebook

toronto_df = pd.read_csv("test.csv",sep=';')
toronto_df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %% [markdown]
# ### Delete the 'Not Assigned' Boroughs

# %%
toronto_df=df = toronto_df.drop(toronto_df[toronto_df.Borough == 'Not assigned'].index)

# %%
toronto_df = toronto_df.reset_index(drop=True)
toronto_df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# As it can be seen the neighbourhood with the same postal code are listed on the same row separated by colons

# %%
notass = toronto_df[toronto_df['Neighbourhood'] == 'Not assigned'] 
notass
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# There are not 'Not assigned' neigbourhood with an assigned Borough

# %%
toronto_df.shape
# Out:
# (103, 3)

# %%
toronto_df.to_csv('Canada_data.csv', sep=';', header=True, index=False)

# %% [markdown]
# # CLUSTERING TORONTO

# %% [markdown]
# ### Explore neighbourhood in Toronto

# %% [markdown]
# Number of venues per neighbourhood

# %%
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            58
# Brockton, Parkdale Village, Exhibition Place                           22
# Business reply mail Processing Centre, South Ce...                     16
# CN Tower, King and Spadina, Railway Lands, Harb...                     18
# Central Bay Street                                                     64
# Christie                                                               16
# Church and Wellesley                                                   75
# Commerce Court, Victoria Hotel                                        100
# Davisville                                                             35
# Davisville North                                                       10
# Dufferin, Dovercourt Village                                           14
# ...

# %% [markdown]
# ## Explore each neighbourhood

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
